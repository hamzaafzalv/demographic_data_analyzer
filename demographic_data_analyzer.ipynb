# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('adult-data.csv')

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df['race']
# Out:
# 0        White
# 1        White
# 2        White
# 3        Black
# 4        Black
#          ...
# 32556    White
# 32557    White
# 32558    White
# 32559    White
# 32560    White
# Name: race, Length: 32561, dtype: object

# %%
df.loc[df['race'] == 'White'] #to get all white columns
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 5       37           Private  284582     Masters             14
# 7       52  Self-emp-not-inc  209642     HS-grad              9
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df['race']
# Out:
# 0        White
# 1        White
# 2        White
# 3        Black
# 4        Black
#          ...
# 32556    White
# 32557    White
# 32558    White
# 32559    White
# 32560    White
# Name: race, Length: 32561, dtype: object

# %%
race_df= df['race'].value_counts()

# %%
race_df
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
male_df= df.pivot_table(columns=['sex'], aggfunc='size') #print total number of diff values in the column 
male_df
# Out:
# sex
# Female    10771
# Male      21790
# dtype: int64

# %%
df[['age','sex']]
# Out:
#        age     sex
# 0       39    Male
# 1       50    Male
# 2       38    Male
# 3       53    Male
# 4       28  Female
# ...    ...     ...
# 32556   27  Female
# 32557   40    Male
# 32558   58  Female
# 32559   22    Male
# 32560   52  Female
#
# [32561 rows x 2 columns]

# %%
male_age_df=df.loc[df['sex'] == 'Male', 'age'] #print multiple columns based on a specific value of specific column 
male_age_df.mean()
# Out:
# 39.43354749885268

# %%
total_bachelors = df.loc[df['education']=='Bachelors', 'education']  #gets total bachelor students
total_bachelors
# Out:
# 0        Bachelors
# 1        Bachelors
# 4        Bachelors
# 9        Bachelors
# 11       Bachelors
#            ...
# 32530    Bachelors
# 32531    Bachelors
# 32533    Bachelors
# 32536    Bachelors
# 32538    Bachelors
# Name: education, Length: 5355, dtype: object

# %%
df['education'].size #gets total education columns size
# Out:
# 32561

# %%
bachelor_perct = (total_bachelors.size / df['education'].size) * 100
bachelor_perct
# Out:
# 16.44605509658794

# %%
High_Ed_Total = df.loc[df['education'].isin(['Doctorate','Masters','Bachelors']),'education'].size #get rows based on column which contain x,y,z
High_Ed_Total  
High_Ed =df.loc[df['education'].isin(['Doctorate','Masters','Bachelors']),'education']
High_Ed
# Out:
# 0        Bachelors
# 1        Bachelors
# 4        Bachelors
# 5          Masters
# 8          Masters
#            ...
# 32538    Bachelors
# 32539    Doctorate
# 32544      Masters
# 32553      Masters
# 32554      Masters
# Name: education, Length: 7491, dtype: object

# %%
High_Ed_Perct = (High_Ed_Total / df['education'].size) * 100
High_Ed_Perct
# Out:
# 23.006050182733944

# %%
Salary_Perct = (df.loc[df['salary'] == '>50K','salary'].size / df['salary'].size) *100
Salary_Perct
# Out:
# 24.080955744602438

# %%
#people without high_ed
not_High_Ed =df.loc[-df['education'].isin(['Doctorate','Masters','Bachelors']),'education'] 
not_High_Ed
# Out:
# 2             HS-grad
# 3                11th
# 6                 9th
# 7             HS-grad
# 10       Some-college
#              ...
# 32556      Assoc-acdm
# 32557         HS-grad
# 32558         HS-grad
# 32559         HS-grad
# 32560         HS-grad
# Name: education, Length: 25070, dtype: object

# %%
q5_df = df[(-df['education'].isin(['Doctorate','Masters','Bachelors'])) & (df['salary'] == '>50K')] #selecting rows based on specific values of specific columns
q5_df[['education','salary']]
# Out:
#           education salary
# 7           HS-grad   >50K
# 10     Some-college   >50K
# 14        Assoc-voc   >50K
# 27     Some-college   >50K
# 38     Some-college   >50K
# ...             ...    ...
# 32518       HS-grad   >50K
# 32519  Some-college   >50K
# 32545    Assoc-acdm   >50K
# 32557       HS-grad   >50K
# 32560       HS-grad   >50K
#
# [4355 rows x 2 columns]

# %%
q5_perct = (q5_df.size / df.size) *100
q5_perct
# Out:
# 13.374896348392248

# %%
min_hrs_week = df['hours-per-week'].min()
min_hrs_week
# Out:
# 1

# %%
q6_df = df.loc[(df['hours-per-week'] == 1) & (df['salary'] == '>50K')]
q6_df
# Out:
#        age  workclass  fnlwgt  education  education-num      marital-status  \
# 189     58  State-gov  109567  Doctorate             16  Married-civ-spouse
# 20072   65          ?   76043    HS-grad              9  Married-civ-spouse
#
#            occupation relationship   race   sex  capital-gain  capital-loss  \
# 189    Prof-specialty      Husband  White  Male             0             0
# 20072               ?      Husband  White  Male             0             0
#
#        hours-per-week native-country salary
# 189                 1  United-States   >50K
# 20072               1  United-States   >50K

# %%
q6_perct = q6_df.size / df.size *100
q6_perct
# Out:
# 0.006142317496391388

# %%
q7_df = df.loc[df['salary'] == '>50K']

q7_df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# ...    ...               ...     ...           ...            ...
# 32539   71                 ?  287372     Doctorate             16
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation   relationship  \
# 7      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
q7_df['native-country'].mode()
# Out:
# 0    United-States
# dtype: object

# %%
q7_df.loc[q7_df['native-country'] == 'United-States']
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 19      43  Self-emp-not-inc  292175       Masters             14
# ...    ...               ...     ...           ...            ...
# 32539   71                 ?  287372     Doctorate             16
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32554   53           Private  321865       Masters             14
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 7      Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
q7_vc = q7_df['native-country'].value_counts()
q7_vc
# Out:
# United-States         7171
# ?                      146
# Philippines             61
# Germany                 44
# India                   40
# Canada                  39
# Mexico                  33
# England                 30
# Italy                   25
# Cuba                    25
# Japan                   24
# Taiwan                  20
# China                   20
# Iran                    18
# South                   16
# Puerto-Rico             12
# Poland                  12
# France                  12
# Jamaica                 10
# El-Salvador              9
# Greece                   8
# Cambodia                 7
# Hong                     6
# Yugoslavia               6
# Ireland                  5
# Vietnam                  5
# Portugal                 4
# Haiti                    4
# Ecuador                  4
# Thailand                 3
# Hungary                  3
# Guatemala                3
# Scotland                 3
# Nicaragua                2
# ...

# %%
q7_perct= (q7_vc[0] / df.size )*100
q7_perct
# Out:
# 1.468218625554088

# %%
India = df.loc[(df['native-country']=='India') & (df['salary'] == '>50K')]
India['occupation'].value_counts()
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Transport-moving     1
# Sales                1
# Adm-clerical         1
# Name: occupation, dtype: int64
